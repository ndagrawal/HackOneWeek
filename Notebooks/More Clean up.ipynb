# %%
import pandas as pd
import pickle


with open('clean_wit_dataframe_no_stemming.pickle', 'rb') as raw_data:
    all_wits = pickle.load(raw_data)

# %%
all_wits
# Out:
#              id                                               area  \
# 0            55                                           VSOnline
# 1            56                                           VSOnline
# 2            58                                           VSOnline
# 3            59                                           VSOnline
# 4           105                                  Domino\DominoCore
# 5           119                                  Domino\DominoCore
# 6           120                         VSOnline\VS Cloud Services
# 7           121                         VSOnline\VS Cloud Services
# 8           122                         VSOnline\VS Cloud Services
# 9           140                                           VSOnline
# 10          141                                           VSOnline
# 11          188                                  Domino\DominoCore
# 12          204                         VSOnline\VS Cloud Services
# ...

# %%
corpus = list()

# %%
title = list(all_wits['title'] + ' ' + all_wits['tags'])
description = list(all_wits['description'])
comments = list(all_wits['comments'])

# %%
noise = 'affect branch affect build affect product language step reproduce'
noise_title = 'title'

# %%
all_wits.loc[all_wits['description'] == noise]['description'] = ''
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
all_wits['title_word_count'] = all_wits.title.apply(lambda x: len(x.split()))

# %%
cleaned = all_wits.loc[all_wits['title_word_count'] != 1 ]

# %%
cleaned.loc[cleaned['description'] == noise]['description'] = ''
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
cleaned
# Out:
#              id                                               area  \
# 0            55                                           VSOnline
# 2            58                                           VSOnline
# 4           105                                  Domino\DominoCore
# 5           119                                  Domino\DominoCore
# 7           121                         VSOnline\VS Cloud Services
# 10          141                                           VSOnline
# 12          204                         VSOnline\VS Cloud Services
# 13          376                                  Domino\DominoCore
# 14          404                                  Domino\DominoCore
# 15          411                            zzz_deprecated_reSearch
# 16          427                            zzz_deprecated_reSearch
# 17          428                            zzz_deprecated_reSearch
# 18          429                            zzz_deprecated_reSearch
# ...
